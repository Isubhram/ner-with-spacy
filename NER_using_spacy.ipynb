# %% [markdown]
# <a href="https://colab.research.google.com/github/Isubhram/ner-with-spacy/blob/main/NER_using_spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from spacy.tokens import DocBin
from spacy import displacy

NER = spacy.load("en_core_web_sm")
from bs4 import BeautifulSoup
import requests
import re
from tqdm import tqdm




article_text="""MV MEDI ADRIATICO    10 LIB DWT 61K   TAMPA 19 SEPT

bod:abt 545mt/mt

last 6 cgo:general cargo, concentrates, general cargo, iron ore, concentrates, clinker

 

 

MV MEDI ADRIATICO

VESSEL (IMO)  : MEDI ADRIATICO  (9774434 )

BUILT         : JUN 10, 2016.

FLAG : LIBERIA.

TYPE : BULKCARRIER.

SDWT : 60,550 METRIC TONNES.

SDRAFT : 12.85 METRES.

LOA : 199.98 METRES.

BEAM : 32.26 METRES.

HOLDS : 5

CAPACITY : GRAIN / BALE.

HOLD#1 : 12594 CU. METRES / 12241 CU. METRES.

HOLD#2 : 16612 CU. METRES / 16264 CU. METRES.

HOLD#3 : 15811 CU. METRES / 15462 CU. METRES.

HOLD#4 : 16597 CU. METRES / 16266 CU. METRES.

HOLD#5 : 14904 CU. METRES / 14684 CU. METRES.

TOTAL : 76518 CU. METRES / 74917 CU. METRES.

HATCHES : JACK KNIFE FOLDING TYPE.

HATCH DIM : HATCH #1: 17670MM X 18600MM.

HATCH #2, #4: 23250MM X 18600MM.

HATCH #3: 21390MM X 18600MM.

HATCH #5: 22320MM X 18600MM.

TANKTOP STR : HOLD #1: 25 MT/SQM.

HOLD #2, #4: 20 MT/SQM.

HOLD #3: 24.3 MT/SQM.

HOLD #5: 24.1 MT/SQM.

CLASS : AMERICAN BUREAU OF SHIPPING.

TPC : 60.10 METRIC TONNES.

GRT : 34049.

NRT : 19883.

CRANES : 4 X 30 METRIC TONNES + GRABS.

HULL : DOUBLE BOTTOM.

P AND I : STANDARD CLUB.

SPEED AND CONSUMPTION:

BALLAST : ABT 13.00 KN ON ABT 20.5 MTS LSIFO.

LADEN : ABT 13.00 KN ON ABT 24.5 MTS LSIFO.

ECO SPEED AND CONSUMPTION WOG

BALLAST ABT 12 KN ON LSIFO ABT17.5MT.

LADEN ABT 11 KN ON LSIFO ABT17.5MT.

IN PORT CONSUMPTION:

IFO IDLE ABT 3.0MT.

IFO WORKING ABT 6.0MT.

ADA

 

B.RGDS./JOHNSON

office line:0086 10 85934611

mobile: 0086 13811677085

Skype: Johnson_ors
-----------------------------------------------------------------------

Ocean Robin Shipping Holding

Email: hdy@oceanrobin.cn"""

text2= NER(article_text)
for word in text2.ents:
    print(word.text,word.label_)

spacy.explain("PRODUCT")
spacy.explain("LOC")
spacy.explain("DATE")
spacy.explain("ORDINAL")
spacy.explain("MONEY")
spacy.explain("QUANTITY")
displacy.render(text2,style="ent",jupyter=True)
# Out:
# MEDI ADRIATICO     ORG
# 10 CARDINAL
# LIB ORG
# K   TAMPA ORG
# SEPT ORG
# 545mt ORG
# MEDI ORG
# IMO ORG
# 9774434 DATE
# 10, 2016 DATE
# 60,550 CARDINAL
# 12.85 CARDINAL
# 32.26 CARDINAL
# 5
#
#  CARDINAL
# 12594 DATE
# CU ORG
# 12241 DATE
# CU ORG
# 16612 DATE
# CU ORG
# CU ORG
# 15811 DATE
# CU ORG
# 15462 DATE
# CU ORG
# 16597 DATE
# CU ORG
# 16266 DATE
# CU ORG
# 14904 DATE
# CU PERSON
# 14684 DATE
# CU ORG
# CU ORG
# 74917 DATE
# 1 MONEY
# 17670MM X 18600MM CARDINAL
# 2 MONEY
# 4 MONEY
# 3 MONEY
# 21390MM CARDINAL
# 5 MONEY
# 1 MONEY
# 25 CARDINAL
# MT ORG
# 2 MONEY
# 4 MONEY
# 20 CARDINAL
# MT/SQM ORG
# 3 MONEY
# 24.3 CARDINAL
# MT ORG
# 5 MONEY
# 24.1 CARDINAL
# AMERICAN BUREAU OF SHIPPING ORG
# 60.10 CARDINAL
# 34049 CARDINAL
# 19883 DATE
# 4 CARDINAL
# ABT ORG
# 13.00 CARDINAL
# KN ORG
# ABT ORG
# 13.00 CARDINAL
# KN ORG
# ABT ORG
# KN ORG
# KN ORG
# 3.0MT CARDINAL
# ADA
#
#
#
# B.RGDS./JOHNSON ORG
# line:0086 10 85934611 DATE
# 13811677085 CARDINAL
# Ocean Robin Shipping Holding
#
# Email ORG
# hdy@oceanrobin.cn CARDINAL
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">MV
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MEDI ADRIATICO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LIB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  DWT 61
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     K   TAMPA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  19
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEPT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br>bod:abt
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     545mt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /mt</br></br>last 6 cgo:general cargo, concentrates, general cargo, iron ore, concentrates, clinker</br></br> </br></br> </br></br>MV
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MEDI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ADRIATICO</br></br>VESSEL (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IMO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# )  : MEDI ADRIATICO  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9774434
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  )</br></br>BUILT         : JUN
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10, 2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>FLAG : LIBERIA.</br></br>TYPE : BULKCARRIER.</br></br>SDWT :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     60,550
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  METRIC TONNES.</br></br>SDRAFT :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12.85
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  METRES.</br></br>LOA : 199.98 METRES.</br></br>BEAM :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     32.26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  METRES.</br></br>HOLDS :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# CAPACITY : GRAIN / BALE.</br></br>HOLD#1 :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12594
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . METRES /
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12241
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . METRES.</br></br>HOLD#2 :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16612
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . METRES / 16264
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . METRES.</br></br>HOLD#3 :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15811
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . METRES /
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15462
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.
